# %%
import pandas as pd

# %%
spcpath = "../Data/SPC_TripSummaries_44Districts.xlsx"
spcxls = pd.ExcelFile(spcpath)
spcxls.sheet_names  # see all sheet names
#xl.parse(sheet_name)  # read a specific sheet to DataFrame
#{sheet_name: spcxls.parse(sheet_name) for sheet_name in spcxls.sheet_names}
# Out:
# ['T1_HBW_TotPers',
#  'T2_HBO_TotPers',
#  'T3_NHB_TotPers',
#  'T4_HBW_HwyVeh',
#  'T5_HBO_HwyVeh',
#  'T6_NHB_HwyVeh',
#  'T7_HBW_TranPers',
#  'T8_HBO_TranPers',
#  'T9_NHB_TranPers',
#  'T10_HBW_SOV',
#  'T11_HBW_HOV2',
#  'T12_HBW_HOV3',
#  'T13_HBW_HOV4+',
#  'T14_HBW_ModeShare',
#  'T15_HBO_ModeShare',
#  'T16_NHB_ModeShare']

# %%
trans_hbw_tb = pd.read_excel(spcxls, 'T7_HBW_TranPers')
trans_hbo_tb = pd.read_excel(spcxls, 'T8_HBO_TranPers')
trans_nhb_tb = pd.read_excel(spcxls, 'T9_NHB_TranPers')

# %%
dis_names = list(trans_hbw.iloc[5:49,1])
dis_dict = { i : dis_names[i-1] for i in range(1, len(dis_names)+1 ) }
dis_dict
# Out:
# {1: 'Pittsburgh Chateau Area',
#  2: 'Pittsburgh Lower North Side',
#  3: 'Pittsburgh Upper North Side',
#  4: 'Allegheny County Northwest',
#  5: 'Allegheny County North (remainder)',
#  6: 'Hazelwood',
#  7: 'Squirrel Hill',
#  8: 'Oakland',
#  9: 'South Side',
#  10: 'Shadyside',
#  11: 'Waterfront (West Homestead Homestead Munhall(part))',
#  12: 'Downtown',
#  13: 'East Liberty',
#  14: 'Strip District',
#  15: 'Pittsburgh East (remainder)',
#  16: 'Hays Lincoln Place',
#  17: 'Verona Oakmont Penn Hills',
#  18: 'Plum Borough',
#  19: 'Monroeville Pitcairn Turtle Creek',
#  20: 'Wilkinsburg Wilkins Braddock and vicinity',
#  21: 'Wilmerding Wall North Versailles',
#  22: 'McKeesport White Oak',
#  23: 'Lincoln Liberty Port Vue',
#  24: 'Elizabeth Forward South Versailles',
#  25: 'Munhall Whitaker Duquesne',
#  26: 'Baldwin Brentwood Whitehall West Mifflin',
#  27: 'Allegheny County Southeast (remainder)',
#  28: 'Allegheny County West',
#  29: 'Armstrong County East',
# ...

# %%
trans_hbw = trans_hbw_tb.iloc[5:49,3:47]
trans_hbw.columns = dis_dict.values()
trans_hbw
# Out:
#    Pittsburgh Chateau Area Pittsburgh Lower North Side  \
# 5                        1                          29
# 6                        2                          31
# 7                        3                          54
# 8                        4                         108
# 9                        5                          44
# 10                       6                           5
# 11                       7                          15
# 12                       8                          17
# 13                       9                          14
# 14                      10                           7
# 15                      11                           4
# 16                      12                          17
# 17                      13                           5
# 18                      14                           2
# 19                      15                          29
# 20                      16                           1
# ...

# %%
def extract_tab(excel, sheet_name):
    sheet_df = pd.read_excel(excel, sheet_name)
    sub_df = sheet_df.iloc[5:49,4:48]
    sub_df.columns = dis_dict.values()
    return(sub_df)

# %%
spc_df_dict_2020 = {sheet_name: extract_tab(spcxls, sheet_name) for sheet_name in spcxls.sheet_names}

# %%
spc_df_dict_2020['T9_NHB_TranPers']

# %%
trans_all = spc_df_dict_2020['T7_HBW_TranPers']
print(trans_all.iloc[0:3,0:3])
trans_all = trans_all.add(spc_df_dict_2020['T8_HBO_TranPers'], fill_value=0)
print(trans_all.iloc[0:3,0:3])
trans_all = trans_all.add(spc_df_dict_2020['T9_NHB_TranPers'], fill_value=0)
print(trans_all.iloc[0:3,0:3])
trans_all
# Out:
#   Pittsburgh Chateau Area  Pittsburgh Lower North Side  \
# 5                      29                         49.0
# 6                      31                         37.0
# 7                      54                        118.0
#
#    Pittsburgh Upper North Side
# 5                         10.0
# 6                          9.0
# 7                         25.0
#   Pittsburgh Chateau Area  Pittsburgh Lower North Side  \
# 5                      62                         93.0
# 6                      76                         74.0
# 7                     119                        211.0
#
#    Pittsburgh Upper North Side
# 5                         26.0
# 6                         27.0
# 7                         61.0
#   Pittsburgh Chateau Area  Pittsburgh Lower North Side  \
# 5                      65                         97.0
# 6                      89                         84.0
# 7                     123                        215.0
#
#    Pittsburgh Upper North Side
# ...
