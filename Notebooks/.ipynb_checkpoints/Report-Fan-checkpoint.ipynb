# %% [markdown]
# # Exploring and Visualizing Beyond the East Busway Data
# ## Matthew Samach

# %% [markdown]
# ## Reading in Data Using Pandas

# %%
raw_data = pd.read_csv("../Data/responses_anonymous.csv", encoding = "ISO-8859-1")
raw_data.head(1)
# Out:
#                                      id           addr            timestamp  \
# 0  426926b2-be9a-4d8e-8aa6-423714dee82f  172.58.43.140  2019-08-03T18:35:41
#
#                                 3 - Area of interest  \
# 0  ['McKeesport and the Mon Valley', 'Monroeville...
#
#      4 - Communities of interest  \
# 0  ['McKeesport', 'Monroeville']
#
#                                     5 - Destinations  \
# 0  ['Aldi Store #97', 'Centers for Rehab Services...
#
#                   6 - Corridor preference      7 - Pittsburgh areas  \
# 0  ['Mon Valley via Westinghouse Bridge']  ['Oakland (Pittsburgh)']
#
#   8 - Allegheny County areas              9 - PAAC Routes Used  \
# 0                         []  ['P1 - East Busway - All Stops']
#
#   10 - Routing Type Preference               11 - Current Transit Usage  \
# 0                        ['2']  ['Rarely, maybe a couple times a year']
#
#   12 - Other Transport Used  \
# 0           ['Private car']
#
#                        12 - Why Other Transport Used             13 - Age  \
# 0  ["Transit isn't reliable to get me where I'm g...  ['65-74 years old']
#
#      13 - Employment status                 13 - Where From 14 - Gender  \
# 0  ['Full-time employment']  ['Regent Square (Pittsburgh)']     ['Man']
#
#                        14 - Race 15 - Comments
# 0  ['Black or African American']          ['']

# %%
county_gis = pd.read_csv('../Data/Allegheny_County_Municipal_Boundaries.csv')
county_gis.head(1)
# Out:
#    OBJECTID      NAME     TYPE             LABEL                     COG  \
# 0         1  CHESWICK  BOROUGH  Cheswick Borough  Allegheny Valley North
#
#             SCHOOLD  CONGDIST   FIPS REGION       ACRES      SQMI  MUNICODE  \
# 0  Allegheny Valley         4  13392     NH  350.191284  0.547174       815
#
#    CNTL_ID  CNTYCOUNCIL     EOC ASSESSORTERRITORY      VALUATIONAREA  \
# 0     3100            7  NEWCOM              East  Alle-Kiski Valley
#
#    YEARCONVERTED                              GlobalID
# 0           1966  f29648dc-0d4f-4e35-8f2d-7b465dcff308

# %%
pgh_gis = pd.read_csv('../Data/pgh_neighborhoods.csv')
pgh_gis.head(2)
# Out:
#    objectid  fid_blockg  statefp10  countyfp10  tractce10  blkgrpce10  \
# 0         1         0.0       42.0         3.0    40500.0         1.0
# 1         2         1.0       42.0         3.0    40400.0         1.0
#
#         geoid10     namelsad10 mtfcc10 funcstat10  ...    shape_le_1  \
# 0  4.200304e+11  Block Group 1   G5030          S  ...  11526.863222
# 1  4.200304e+11  Block Group 1   G5030          S  ...  20941.386025
#
#      shape_ar_1  page_number  plannerassign  created_user  \
# 0  7.843108e+06           15  Derek Dauphin     pgh.admin
# 1  1.390463e+07           15  Derek Dauphin     pgh.admin
#
#                created_date  last_edited_user          last_edited_date  \
# 0  2019-10-23T14:17:16.403Z         pgh.admin  2019-10-23T14:17:16.403Z
# 1  2019-10-23T14:17:16.403Z         pgh.admin  2019-10-23T14:17:16.403Z
#
#     Shape__Area  Shape__Length
# 0  7.842997e+06   11525.904546
# 1  1.390469e+07   20945.562570
#
# [2 rows x 37 columns]

# %%
pivot = pd.read_csv("../Data/pivot_anon_source.csv", encoding = "ISO-8859-1")
pivot.head(2)
# Out:
#                                      id            timestamp  \
# 0  009a7c74-36df-485b-b9ab-4d89d73ae94c  2019-08-23T12:16:01
# 1  009a7c74-36df-485b-b9ab-4d89d73ae94c  2019-08-23T12:16:01
#
#                       question                         answer
# 0         3 - Area of interest  McKeesport and the Mon Valley
# 1  4 - Communities of interest                       Duquesne

# %% [markdown]
# Data are not in First Normal Form (there are multiple values per cell in some cases). Will have to write a function to move data into that form.

# %%
data = helpers.clean(raw_data)
data.head(1)
# Out:
#                                      id           addr            timestamp  \
# 0  426926b2-be9a-4d8e-8aa6-423714dee82f  172.58.43.140  2019-08-03T18:35:41
#
#                                 3 - Area of interest  \
# 0  McKeesport and the Mon Valley| Monroeville and...
#
#   4 - Communities of interest  \
# 0     McKeesport| Monroeville
#
#                                     5 - Destinations  \
# 0  Aldi Store #97| Centers for Rehab Services For...
#
#               6 - Corridor preference  7 - Pittsburgh areas  \
# 0  Mon Valley via Westinghouse Bridge  Oakland (Pittsburgh)
#
#   8 - Allegheny County areas          9 - PAAC Routes Used  \
# 0                             P1 - East Busway - All Stops
#
#   10 - Routing Type Preference           11 - Current Transit Usage  \
# 0                            2  Rarely, maybe a couple times a year
#
#   12 - Other Transport Used  \
# 0               Private car
#
#                        12 - Why Other Transport Used         13 - Age  \
# 0  Transit isnt reliable to get me where Im going...  65-74 years old
#
#   13 - Employment status             13 - Where From 14 - Gender  \
# 0   Full-time employment  Regent Square (Pittsburgh)         Man
#
#                    14 - Race 15 - Comments
# 0  Black or African American

# %%
data['13 - Where From']
# Out:
# 0            Regent Square (Pittsburgh)
# 1      Squirrel Hill South (Pittsburgh)
# 2                  Forest Hills Borough
# 3                        Rankin Borough
# 4                  West Mifflin Borough
#                      ...
# 513                Turtle Creek Borough
# 514                 Wilkinsburg Borough
# 515                   Swissvale Borough
# 516     Point Breeze North (Pittsburgh)
# 517           East Liberty (Pittsburgh)
# Name: 13 - Where From, Length: 518, dtype: object

# %%
whereHot = helpers.oneHot(dFrame=data, col='13 - Where From')
whereHot.head(1)
# Out:
# 13 - Where From col has 103 unique vals
#                                      id           addr            timestamp  \
# 0  426926b2-be9a-4d8e-8aa6-423714dee82f  172.58.43.140  2019-08-03T18:35:41
#
#                                 3 - Area of interest  \
# 0  McKeesport and the Mon Valley| Monroeville and...
#
#   4 - Communities of interest  \
# 0     McKeesport| Monroeville
#
#                                     5 - Destinations  \
# 0  Aldi Store #97| Centers for Rehab Services For...
#
#               6 - Corridor preference  7 - Pittsburgh areas  \
# 0  Mon Valley via Westinghouse Bridge  Oakland (Pittsburgh)
#
#   8 - Allegheny County areas          9 - PAAC Routes Used  ...  \
# 0                             P1 - East Busway - All Stops  ...
#
#   White Oak Borough Whitehall Borough Wilkins Township Wilkinsburg Borough  \
# 0                 0                 0                0                   0
#
#   Wilmerding Borough mck mon valley portVue southside westend
# 0                  0   0          0       0         0       0
#
# [1 rows x 123 columns]

# %%
mult_col_dict = {3 : '3 - Area of interest', 
                4 : '4 - Communities of interest', 
                5 : '5 - Destinations', 
                7 : '7 - Pittsburgh areas', 
                8 : '8 - Allegheny County areas', 
                9 : '9 - PAAC Routes Used', 
                10 : '10 - Routing Type Preference', 
                12 : '12 - Other Transport Used', 
                13 : '12 - Why Other Transport Used', 
                16 : '13 - Where From'}

# %%
raw_data.columns[list(mult_col_dict.keys())]
# Out:
# Index(['3 - Area of interest', '4 - Communities of interest',
#        '5 - Destinations', '7 - Pittsburgh areas',
#        '8 - Allegheny County areas', '9 - PAAC Routes Used',
#        '10 - Routing Type Preference', '12 - Other Transport Used',
#        '12 - Why Other Transport Used', '13 - Where From'],
#       dtype='object')

# %%
def find_unique_loc(dFrame, col):
    #locDict = {}
    locs = []
    for i in range(dFrame.shape[0]):
        cell_list = [x.strip() for x in dFrame[col].loc[i].split("|")]
        locs = locs + cell_list
    return(set(locs))

# %%
from_loc = find_unique_loc(data, '13 - Where From')
from_pgh_loc = {x for x in from_loc if re.search('Pittsburgh', x, re.IGNORECASE)}
from_pgh_loc.update(['southside','westend'])
from_out_loc = from_loc - from_pgh_loc
print('{0} PGH neigborhoods, {1} non-PGH municipalities'.format(len(from_pgh_loc), len(from_out_loc)))
# Out:
# 46 PGH neigborhoods, 57 non-PGH municipalities

# %%
def countyMatcher(placelist, gisTown, gisType, gisAll):
    ''' 
    Takes in a location column and returns a matcher to a GIS asset
    Matches on the strict name, then finds municipality type
    '''
    # List for dicts for easy dataframe creation
    dict_list = []

    unusual_match = {'2434 south braddock ave': ('SWISSVALE', 'Swissvale Borough', 'BOROUGH'),
                     'mck': ('MCKEESPORT','McKeesport', 'CITY'),
                     'mon valley': ('','',''),
                     'Wexford': ('PINE', 'Pine Township', 'TOWNSHIP'),
                     'Bethel Park Borough': ('BETHEL PARK', 'Bethel Park Municipality', 'MUNICIPALI',
                     'Pittsburgh': ('PITTSBURGH', 'Pittsburgh', 'CITY'))}
    # extracting municipality type
    p = re.compile("(Township|Borough|Municipality|City)")
    # Iterating over nonpgh places
    for place in placelist:
        # New dict for storing data
        dict_ = {}
        # Find muni type first

        # Replace pittsburgh:
        if re.search('Pittsburgh', place, re.IGNORECASE):
            mName = (unusual_match['Pittsburgh'][0], 100)
            aMatch = (unusual_match['Pittsburgh'][1], 100)
            tMatch = (unusual_match['Pittsburgh'][2], 100)
        # Take out messy matches o
        elif place in unusual_match.keys():
            mName = (unusual_match[place][0], 100)
            aMatch = (unusual_match[place][1], 100)
            tMatch = (unusual_match[place][2], 100)
        # Use our method to find best match, we can set a threshold here
        else:
            type_result = p.search(place, re.IGNORECASE)
            if type_result:
                muni_type = type_result.group(1)
                tMatch = process.extractOne(muni_type, gisType, scorer=fuzz.ratio)
            else:
                tMatch = ('', 100)
            mName = process.extractOne(place, gisTown,  scorer=fuzz.ratio)#, score_cutoff = 60)
            aMatch = process.extractOne(place, gisAll,  scorer=fuzz.ratio)
        
        dict_.update({"from_ppt" : place})
        dict_.update({"from_LabelGIS" : aMatch[0]})
        dict_.update({"labelScore" : aMatch[1]})
        dict_.update({"from_NameGIS" : mName[0]})
        dict_.update({"nameScore" : mName[1]})
        dict_.update({"from_TypeGIS" : tMatch[0]})
        dict_.update({"typeScore" : tMatch[1]})
        dict_list.append(dict_)

    matches_all = pd.DataFrame(dict_list)
    return(matches_all)

# %%
fromCounty = countyMatcher(from_loc, county_gis.NAME, county_gis.TYPE, county_gis.LABEL)
fromCounty
# Out:
#                      from_ppt              from_LabelGIS  labelScore  \
# 0          Wilmerding Borough         Wilmerding Borough         100
# 1                    Duquesne                   Duquesne         100
# 2        Turtle Creek Borough       Turtle Creek Borough         100
# 3          Dravosburg Borough         Dravosburg Borough         100
# 4            Millvale Borough           Millvale Borough         100
# 5                     portVue           Port Vue Borough          61
# 6           Swissvale Borough          Swissvale Borough         100
# 7         Bethel Park Borough   Bethel Park Municipality         100
# 8            Chalfant Borough           Chalfant Borough         100
# 9           Glassport Borough          Glassport Borough         100
# 10           Trafford Borough           Trafford Borough         100
# 11            Oakmont Borough            Oakmont Borough         100
# 12           Port Vue Borough           Port Vue Borough         100
# 13            Crafton Borough            Crafton Borough         100
# 14           Pitcairn Borough           Pitcairn Borough         100
# 15           Bellevue Borough           Bellevue Borough         100
# 16     West Homestead Borough     West Homestead Borough         100
# 17     Braddock Hills Borough     Braddock Hills Borough         100
# 18            Lincoln Borough            Lincoln Borough         100
# 19        Wilkinsburg Borough        Wilkinsburg Borough         100
# 20               Plum Borough               Plum Borough         100
# 21       Forest Hills Borough       Forest Hills Borough         100
# 22       West Mifflin Borough       West Mifflin Borough         100
# 23          Homestead Borough          Homestead Borough         100
# 24           Wilkins Township           Wilkins Township         100
# 25             Rankin Borough             Rankin Borough         100
# 26           Edgewood Borough           Edgewood Borough         100
# 27           Braddock Borough           Braddock Borough         100
# 28    2434 south braddock ave          Swissvale Borough         100
# 29       McKees Rocks Borough       McKees Rocks Borough         100
# 30            Dormont Borough            Dormont Borough         100
# 31                Monroeville   Monroeville Municipality          63
# 32     North Fayette Township     North Fayette Township         100
# 33          Whitehall Borough          Whitehall Borough         100
# 34          Marshall Township          Marshall Township         100
# 35           Hampton Township           Hampton Township         100
# 36    East McKeesport Borough    East McKeesport Borough         100
# 37          Churchill Borough          Churchill Borough         100
# 38          White Oak Borough          White Oak Borough         100
# 39                 Liberty pa            Liberty Borough          64
# 40        Penn Hills Township           Neville Township          74
# 41                   Clairton                   Clairton         100
# 42             Verona Borough             Verona Borough         100
# 43                 McKeesport                 McKeesport         100
# 44                 mon valley                                    100
# 45  North Versailles Township  North Versailles Township         100
# 46           Reserve Township           Reserve Township         100
# 47            Aleppo Township            Aleppo Township         100
# 48                        mck                 McKeesport         100
# 49            Shaler Township            Shaler Township         100
# 50     North Braddock Borough     North Braddock Borough         100
# 51                    Wexford              Pine Township         100
# 52             Avalon Borough             Avalon Borough         100
# 53          Brentwood Borough          Brentwood Borough         100
# 54            Munhall Borough            Munhall Borough         100
# 55          Edgeworth Borough          Edgeworth Borough         100
# 56           Whitaker Borough           Whitaker Borough         100
#
#         from_NameGIS  nameScore from_TypeGIS  typeScore
# 0         WILMERDING         71      BOROUGH        100
# 1           DUQUESNE        100                     100
# 2       TURTLE CREEK         75      BOROUGH        100
# 3         DRAVOSBURG         71      BOROUGH        100
# 4           MILLVALE         67      BOROUGH        100
# 5           PORT VUE         93                     100
# 6          SWISSVALE         69      BOROUGH        100
# 7        BETHEL PARK        100   MUNICIPALI        100
# 8           CHALFANT         67      BOROUGH        100
# 9          GLASSPORT         69      BOROUGH        100
# 10          TRAFFORD         67      BOROUGH        100
# 11           OAKMONT         64      BOROUGH        100
# 12          PORT VUE         67      BOROUGH        100
# 13           CRAFTON         64      BOROUGH        100
# 14          PITCAIRN         67      BOROUGH        100
# 15          BELLEVUE         67      BOROUGH        100
# 16    WEST HOMESTEAD         78      BOROUGH        100
# 17    BRADDOCK HILLS         78      BOROUGH        100
# 18           LINCOLN         64      BOROUGH        100
# 19       WILKINSBURG         73      BOROUGH        100
# 20              PLUM         50      BOROUGH        100
# 21      FOREST HILLS         75      BOROUGH        100
# 22      WEST MIFFLIN         75      BOROUGH        100
# 23         HOMESTEAD         69      BOROUGH        100
# 24           WILKINS         61     TOWNSHIP        100
# 25            RANKIN         60      BOROUGH        100
# 26          EDGEWOOD         67      BOROUGH        100
# 27    BRADDOCK HILLS         67      BOROUGH        100
# 28         SWISSVALE        100      BOROUGH        100
# 29      MCKEES ROCKS         75      BOROUGH        100
# 30           DORMONT         64      BOROUGH        100
# 31       MONROEVILLE        100                     100
# 32     NORTH FAYETTE         74     TOWNSHIP        100
# 33         WHITEHALL         69      BOROUGH        100
# 34          MARSHALL         64     TOWNSHIP        100
# 35           HAMPTON         61     TOWNSHIP        100
# 36   EAST MCKEESPORT         79      BOROUGH        100
# 37         CHURCHILL         69      BOROUGH        100
# 38         WHITE OAK         69      BOROUGH        100
# 39           LIBERTY         82                     100
# 40        PENN HILLS         69     TOWNSHIP        100
# 41          CLAIRTON        100                     100
# 42            VERONA         60      BOROUGH        100
# 43        MCKEESPORT        100                     100
# 44                          100                     100
# 45  NORTH VERSAILLES         78     TOWNSHIP        100
# 46           RESERVE         61     TOWNSHIP        100
# 47            ALEPPO         57     TOWNSHIP        100
# 48        MCKEESPORT        100         CITY        100
# 49            SHALER         57     TOWNSHIP        100
# 50    NORTH BRADDOCK         78      BOROUGH        100
# 51              PINE        100     TOWNSHIP        100
# 52            AVALON         60      BOROUGH        100
# 53         BRENTWOOD         69      BOROUGH        100
# 54           MUNHALL         64      BOROUGH        100
# 55         EDGEWORTH         69      BOROUGH        100
# 56          WHITAKER         67      BOROUGH        100

# %%
county_gis[['NAME', 'LABEL', 'TYPE', 'COG', 'FIPS', 'MUNICODE', 'OBJECTID', 'REGION', 'SQMI', 'ACRES']]
# Out:
#                   NAME                      LABEL        TYPE  \
# 0             CHESWICK           Cheswick Borough     BOROUGH
# 1            EDGEWORTH          Edgeworth Borough     BOROUGH
# 2            SEWICKLEY          Sewickley Borough     BOROUGH
# 3    SEWICKLEY HEIGHTS  Sewickley Heights Borough     BOROUGH
# 4               HARMAR            Harmar Township    TOWNSHIP
# ..                 ...                        ...         ...
# 125            KILBUCK           Kilbuck Township    TOWNSHIP
# 126    EAST MCKEESPORT    East McKeesport Borough     BOROUGH
# 127         PITTSBURGH                 Pittsburgh        CITY
# 128         PENN HILLS    Penn Hills Municipality  MUNICIPALI
# 129       FOREST HILLS       Forest Hills Borough     BOROUGH
#
#                         COG   FIPS  MUNICODE  OBJECTID REGION       SQMI  \
# 0    Allegheny Valley North  13392       815         1     NH   0.547174
# 1             Quaker Valley  22576       824         4     AA   1.610538
# 2             Quaker Valley  69376       851         5     AA   1.122359
# 3                            69400       869         6     AA   7.404672
# 4    Allegheny Valley North  32624       915         8     NH   6.345092
# ..                      ...    ...       ...       ...    ...        ...
# 125           Quaker Valley  39624       920     31505     NH   2.650067
# 126     Turtle Creek Valley  21496       821     31510     MV   0.378998
# 127                          61000       100     31908    PGH        NaN
# 128     Turtle Creek Valley  59032       934     35908     ES  19.462078
# 129     Turtle Creek Valley  26592       828     36708     ES   1.548055
#
#             ACRES
# 0      350.191284
# 1     1030.743774
# 2      718.309570
# 3     4738.989746
# 4     4060.858643
# ..            ...
# 125   1696.042969
# 126    242.558563
# 127           NaN
# 128  12455.728516
# 129    990.755310
#
# [130 rows x 10 columns]

# %%
dataNew = pd.merge(data, fromCounty,  how='left', left_on=['A_c1','c2'], right_on = ['B_c1','c2'])
pd.concat([data,county_gis[['NAME', 'LABEL', 'TYPE', 'COG', 'FIPS', 'MUNICODE', 'OBJECTID', 'REGION', 'SQMI', 'ACRES']]], axis=1)
dataNew[['13 - Where From', 'LABEL', 'COG']]
# Out:
#                       13 - Where From                      LABEL  \
# 0          Regent Square (Pittsburgh)           Cheswick Borough
# 1    Squirrel Hill South (Pittsburgh)          Edgeworth Borough
# 2                Forest Hills Borough          Sewickley Borough
# 3                      Rankin Borough  Sewickley Heights Borough
# 4                West Mifflin Borough            Harmar Township
# ..                                ...                        ...
# 513              Turtle Creek Borough                        NaN
# 514               Wilkinsburg Borough                        NaN
# 515                 Swissvale Borough                        NaN
# 516   Point Breeze North (Pittsburgh)                        NaN
# 517         East Liberty (Pittsburgh)                        NaN
#
#                         COG
# 0    Allegheny Valley North
# 1             Quaker Valley
# 2             Quaker Valley
# 3
# 4    Allegheny Valley North
# ..                      ...
# 513                     NaN
# 514                     NaN
# 515                     NaN
# 516                     NaN
# 517                     NaN
#
# [518 rows x 3 columns]
