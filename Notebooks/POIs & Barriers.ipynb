# %% [markdown]
# For different major Points of Interest, we will be looking at the barriers to transit that survey respondents indicated

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import numpy as np
import warnings
import itertools
import helpers as hp
import re
import json 
  
warnings.filterwarnings('ignore')

# %matplotlib inline

# %% [markdown]
# Importing CiviMapper Mapping

# %%
with open('../Data/CivicMapperData/surveyConfig.json') as json_file: 
    geoDict = json.load(json_file) 
geoDict
# Out:
# {'survey': [{'id': 1,
#    'title': 'Welcome!',
#    'content': '',
#    'desc': '\nPittsburghers for Public Transit (PPT) knows that transit planning has to happen from the ground up. When our community resources are spent on improving bus service to the Mon Valley and Eastern Suburbs, what improvements are most important? Where do you think the fast bus corridor beyond the East Busway should go? \n\nWe\'re giving you an interactive map so you can test it out yourself and give us your recommendation for you and your neighbors. You can also click on the map to select the options.\n\nIf you haven\'t yet, <a href="/presentation/" target="_blank">see why we\'re doing this</a>. Together we are making a plan for how to extend the busway benefits through the Mon Valley and Eastern Suburbs with on-street bus infrastructure improvements, and, with your help, identify some previously overlooked sites in the area.\n',
#    'formGroups': [],
#    'mapView': {'center': [-79.9490537, 40.4164496], 'zoom': 11},
#    'optional': True,
#    'answered': True,
#    'answerCountLimit': False,
#    'categoryFilter': False,
#    'highlightOnSelect': True},
#   {'id': 100,
#    'title': 'How this tool works',
#    'content': '',
#    'desc': "Now for the fun part!\r\n\nAs you work through the survey, you'll see a number of different things appear on the map.\n\n##### The East Busway\n\n![](/static/assets/legend_eb.png)\n\nThe East Busway is shown as a solid, purple/fuschia line. Stops along it are shown as white dots with a purple/fuschia outline. The stops are labeled with their names.\n\n##### Proposed Bus Rapid Transit routes\n\n![](/static/assets/legend_brt.png)\n\nSmall dashed purple lines indicate the roads where Bus Rapid Transit has been proposed by the Port Authority. Note that some of these routes overlap with the East Busway.\n\n##### Areas of interest\n\n![](/static/assets/legend_areas2.png)\n\nA dashed blue line indicates a general area of interest. These aren't official boundaries, but may sound familiar (such as 'East End', or 'South Hills'). You'll see these in a few questions.\n\n##### Municipal Boundaries\n\n![](/static/assets/legend_communities.png)\n\nThese solid blue lines, with a blue background, indicate actual official municipal boundaries. In this survey, you'll only see these for communities in the Mon Valley and Eastern Suburbs.\n\n##### Destinations / Points of Interest\n\n![](/static/assets/legend_poi.png)\n\nThese dots indicate points of interest: libraries, hospitals, parks, etc. When you see these on the map in one of the questions, you'll only see one category/color at a time. Zoom into the map and labels for these items will appear.\n\n##### Potential Corridors\n\n![](/static/assets/legend_corridor.png)\n\nDashed orange lines indicate the corridors that PPT thinks might be candidates for future service improvements. These are the corridors we'll ask you about in one question during the survey.\n\r\n<hr></hr>Pan and zoom around the map with your mouse (or finger, if using a touchscreen device).\r\nZoom in far enough you'll see all existing transit routes.\r\nSome survey questions let you click on either the map or a checkbox to make a choice.\r\nA map legend is available from the menu above.",
#    'formGroups': [],
#    'mapView': False,
#    'answered': False,
#    'answerCountLimit': False,
#    'categoryFilter': False,
#    'highlightOnSelect': True},
#   {'id': 2,
#    'title': 'Select your interest area',
#    'content': "The East Busway ends at Swissvale, but that doesn't mean that fast, reliable service beyond the busway isn't possible. PPT is looking at two areas that on-street Bus Rapid Transit from the East Busway could serve: McKeesport and the Mon Valley (south) and Monroeville and Eastern Suburbs (east).\n\n The idea is that transit street improvements would allow buses from the Mon Valley and the Eastern Suburbs to access the transit network more quickly and reliably (and especially connect to the transit hubs of Downtown, Oakland, and East Liberty), and really improve transportation access to and from these outlying communities.",
#    'desc': "Select the region you're interested in because you live, work, or travel there often. If you spend a lot of time in both the Mon Valley and Eastern Suburbs, select both.",
#    'formGroups': [{'id': 1,
#      'forms': [{'id': 1,
#        'text': 'McKeesport and the Mon Valley',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-areas',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 2,
#        'text': 'Monroeville and Eastern Suburbs',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-areas',
#        'skipFilter': None,
#        'fgidx': 0}],
#      'layerSource': {'id': 'ppt-concept-areas',
#       'bounds': [-79.9321175153484,
#        40.3197462222566,
#        -79.7044647289513,
#        40.4611891872028],
#       'filteredByRelated': True,
#       'filteredBySelection': True},
#      'desc': False,
#      'type': 'checkbox-group',
#      'optional': False,
#      'answered': False,
#      'fgidx': 0}],
#    'mapView': {'center': [-79.8340136, 40.4026109], 'zoom': 11},
#    'optional': False,
#    'answered': False,
#    'answerCountLimit': False,
#    'categoryFilter': False,
#    'highlightOnSelect': True},
#   {'id': 3,
#    'title': 'Select the communities you want to travel to or from in that region.',
#    'content': 'Within your area of interest, select the communities that you:\n\n* need to travel to on a regular basis using transit\n* Would like to get to and from on buses to\n* think good transit access could be a real benefit for.\n\nSelect as many communities as you need&mdash;it will help us understand where demand for transit is.',
#    'desc': '',
#    'formGroups': [{'id': 1,
#      'forms': [{'id': 10,
#        'text': 'Braddock Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 25,
#        'text': 'Braddock Hills Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 185,
#        'text': 'Chalfant Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 165,
#        'text': 'Churchill Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 100,
#        'text': 'Duquesne',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 70,
#        'text': 'East McKeesport Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 30,
#        'text': 'East Pittsburgh Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 125,
#        'text': 'Edgewood Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 175,
#        'text': 'Forest Hills Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 90,
#        'text': 'Homestead Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 110,
#        'text': 'McKeesport',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 150,
#        'text': 'Monroeville',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 95,
#        'text': 'Munhall Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 20,
#        'text': 'North Braddock Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 75,
#        'text': 'North Versailles Township',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 155,
#        'text': 'Pitcairn Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 5,
#        'text': 'Rankin Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 135,
#        'text': 'Swissvale Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 50,
#        'text': 'Turtle Creek Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 65,
#        'text': 'Wall Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 92,
#        'text': 'West Homestead Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 187,
#        'text': 'West Mifflin Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 186,
#        'text': 'Whitaker Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 145,
#        'text': 'Wilkins Township',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 120,
#        'text': 'Wilkinsburg Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 60,
#        'text': 'Wilmerding Borough',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-communities',
#        'skipFilter': None,
#        'fgidx': 0}],
#      'layerSource': {'id': 'ppt-concept-communities',
#       'bounds': [-79.9321175153484,
#        40.3197462222566,
#        -79.7044647289513,
#        40.4611891872028],
#       'filteredByRelated': True,
#       'filteredBySelection': True},
#      'desc': False,
#      'type': 'checkbox-group',
#      'optional': False,
#      'answered': False,
#      'fgidx': 0}],
#    'mapView': {'center': [-79.8340136, 40.4026109], 'zoom': 11},
#    'optional': False,
#    'answered': False,
#    'answerCountLimit': False,
#    'categoryFilter': False,
#    'highlightOnSelect': True},
#   {'id': 4,
#    'title': 'What specific destinations should be better served by public transit? Select up to five (5).',
#    'content': "What specific destinations are important to you? Search and pick from community destinations in the list below: libraries, schools, grocery stores, etc. Select up to five destinations.\n\nThe search box lets you search from destinations we've identified in the region, but you can also search for specific places or addresses that aren't on the list!\n\nAdditionally, use the filter box to limit the kinds of places that show on the map and in the pick-list.",
#    'desc': 'Use the search bar to type the name of specific place(s) or address(es) in the box below or pick from important community destinations in the list below: libraries, schools, grocery stores, etc',
#    'formGroups': [{'id': 1,
#      'forms': [{'id': 18746,
#        'text': '1 Stop Amish Deli & Gifts',
#        'desc': 'Convenience Store',
#        'detail': '1906 Lincoln Hwy, , PA 15137',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17589,
#        'text': '11th Avenue Playground',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17590,
#        'text': '19th Avenue Playground',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17713,
#        'text': '5th Avenue Playground',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18754,
#        'text': '7 Eleven #36121A',
#        'desc': 'Convenience Store',
#        'detail': '423 James St, , PA 15145',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18729,
#        'text': '7 Eleven #36155',
#        'desc': 'Convenience Store',
#        'detail': '818 Duquesne Blvd, , PA 15110',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18772,
#        'text': 'A & M Market',
#        'desc': 'Convenience Store',
#        'detail': '320 Coal St, , PA 15221',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18582,
#        'text': "A Child's World Day Care Centerâ€”Green Grocer",
#        'desc': 'Farmers Market',
#        'detail': '300 Rankin Blvd., Rankin, PA 15104',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19548,
#        'text': 'ALDI',
#        'desc': 'Supermarket',
#        'detail': None,
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19549,
#        'text': 'ALDI',
#        'desc': 'Supermarket',
#        'detail': None,
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19412,
#        'text': 'Abundant Mercy Ministry',
#        'desc': None,
#        'detail': None,
#        'data': 'Places of Worship',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18178,
#        'text': 'Adler and Krause Card Med Assoc',
#        'desc': 'Primary Care',
#        'detail': '21 Yost at Ardmore Boulevard - Suite 217, Pittsburgh, PA 15221',
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18580,
#        'text': 'Adler and Krause Card Med Assoc',
#        'desc': 'Primary Care',
#        'detail': 'Yost at Ardmore Boulevard - Suite 217, Pittsburgh, PA 15221',
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17746,
#        'text': 'Airbrake Ave. Playground',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18651,
#        'text': "Al's Market",
#        'desc': 'Convenience Store',
#        'detail': '24 Braddock Ave, , PA 15104',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19545,
#        'text': 'Aldi',
#        'desc': 'Supermarket',
#        'detail': '1766 Golden Mile Highway,  , ',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19152,
#        'text': 'Aldi #56',
#        'desc': 'Supermarket',
#        'detail': '2348 Ardmore Blvd, , PA 15221',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19156,
#        'text': 'Aldi #89',
#        'desc': 'Supermarket',
#        'detail': '300 Eden Park Bo, , PA 15132',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19158,
#        'text': 'Aldi Store #97',
#        'desc': 'Supermarket',
#        'detail': '127 7th Av, , PA 15120',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19368,
#        'text': 'All Souls Episcopal Church',
#        'desc': None,
#        'detail': None,
#        'data': 'Places of Worship',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18218,
#        'text': 'Allegheny Center For Digestive Health',
#        'desc': 'Primary Care',
#        'detail': '2550 Mosside Boulevard - 5th Floor, Monroeville, PA 15146',
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18222,
#        'text': 'Allegheny Orthopaedic Associates',
#        'desc': 'Primary Care',
#        'detail': '2580 Haymaker Road - Suite 104, Monroeville, PA 15146',
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18177,
#        'text': 'Alliance Cardiology UPMC',
#        'desc': 'Primary Care',
#        'detail': '21 Yost Boulevard - Suite 216, Pittsburgh, PA 15221',
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17562,
#        'text': 'Alpine Park',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18652,
#        'text': 'Alstan Mini Mart',
#        'desc': 'Convenience Store',
#        'detail': '2516 Monroeville Blvd, , PA 15146',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18653,
#        'text': "American Joe's",
#        'desc': 'Convenience Store',
#        'detail': '2105 Walnut St, , PA 15132',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17482,
#        'text': 'American Legion Memorial Park',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18780,
#        'text': 'American Natural #12',
#        'desc': 'Convenience Store',
#        'detail': '103 22nd Av, , PA 15120',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18783,
#        'text': 'American Natural #5',
#        'desc': 'Convenience Store',
#        'detail': '3800 Walnut St, , PA 15132',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19370,
#        'text': 'Apostolic Faith Church',
#        'desc': None,
#        'detail': None,
#        'data': 'Places of Worship',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19611,
#        'text': 'Ardmore Shopping Center',
#        'desc': None,
#        'detail': None,
#        'data': 'Job Centers / Retail',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18202,
#        'text': 'Arnold Family Practice',
#        'desc': 'Primary Care',
#        'detail': '2400 Ardmore Boulevard - Suite 301, Pittsburgh, PA 15221',
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 16446,
#        'text': 'Auberle',
#        'desc': 'Other Private, Non-Licensed Entity',
#        'detail': '1101 Hartman St, Mc Keesport, PA 15132',
#        'data': 'Schools',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19347,
#        'text': 'Auberle',
#        'desc': 'Social Facility',
#        'detail': None,
#        'data': 'Community and Social Centers',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 16447,
#        'text': 'Auberle Girls Group Home',
#        'desc': 'Other Private, Non-Licensed Entity',
#        'detail': '201 Caldwell Ave, Wilmerding, PA 15148',
#        'data': 'Schools',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 16448,
#        'text': 'Auberle Goal I & II Apts',
#        'desc': 'Other Private, Non-Licensed Entity',
#        'detail': '810 Evans Ave, Mc Keesport, PA 15132',
#        'data': 'Schools',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 16450,
#        'text': 'Auberle Semi-Ind Living Prog',
#        'desc': 'Other Private, Non-Licensed Entity',
#        'detail': '1318 Hamilton St, Mc Keesport, PA 15132',
#        'data': 'Schools',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 16451,
#        'text': 'Auberle Shelter Group Home',
#        'desc': 'Other Private, Non-Licensed Entity',
#        'detail': '122 S 3rd St, Duquesne, PA 15110',
#        'data': 'Schools',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 16452,
#        'text': 'Auberle Youth & Fam Comm Prog',
#        'desc': 'Other Private, Non-Licensed Entity',
#        'detail': '1305 5th Ave, East Mc Keesport, PA 15035',
#        'data': 'Schools',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 16453,
#        'text': 'Augustana Camp Association',
#        'desc': 'Other Private, Non-Licensed Entity',
#        'detail': '7807 Saint Lawrence Ave, Pittsburgh, PA 15218',
#        'data': 'Schools',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17747,
#        'text': 'Avenue U Playground',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18282,
#        'text': 'Avenue to Wellness LLC',
#        'desc': 'Primary Care',
#        'detail': "330 East Eighth Avenue, Homestead, PA <class 'zip'>",
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17848,
#        'text': 'BH-1',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17133,
#        'text': 'BH-2',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18807,
#        'text': 'BP Oil',
#        'desc': 'Convenience Store',
#        'detail': '231 5th Ave, , PA 15132',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18810,
#        'text': 'BP South Braddock',
#        'desc': 'Convenience Store',
#        'detail': '1600 Braddock Av, , PA 15218',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18811,
#        'text': 'BP Stop & Go',
#        'desc': 'Convenience Store',
#        'detail': '638 Brown Av, , PA 15145',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18812,
#        'text': 'BP/ BFS Foods #64',
#        'desc': 'Convenience Store',
#        'detail': '3984 Monroeville Blvd, , PA 15146',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18813,
#        'text': 'BP/ Fueland #216',
#        'desc': 'Convenience Store',
#        'detail': '625 Ardmore Blvd, , PA 15221',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18791,
#        'text': 'Bailie Food Mart',
#        'desc': 'Convenience Store',
#        'detail': '2316 Bailie Ave, , PA 15132',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17211,
#        'text': 'Ballfield',
#        'desc': 'Community',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 16965,
#        'text': 'Barrett El Sch',
#        'desc': 'Regular School, Elementary',
#        'detail': '221 E 12th Ave, Homestead, PA 15120',
#        'data': 'Schools',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17563,
#        'text': 'Beechwood Park',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18795,
#        'text': "Bell's Market",
#        'desc': 'Convenience Store',
#        'detail': '603 Braddock Ave, , PA 15104',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17564,
#        'text': 'Bellwood Park',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17715,
#        'text': 'Bellwood Playground',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19352,
#        'text': 'Bethel Church',
#        'desc': None,
#        'detail': None,
#        'data': 'Places of Worship',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19375,
#        'text': 'Bethlehem Temple Church',
#        'desc': None,
#        'detail': None,
#        'data': 'Places of Worship',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19353,
#        'text': 'Beulah Church',
#        'desc': None,
#        'detail': None,
#        'data': 'Places of Worship',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19376,
#        'text': 'Beulah Park United Methodist Church',
#        'desc': None,
#        'detail': None,
#        'data': 'Places of Worship',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17515,
#        'text': 'Bird & Wildlife Sanctuary - Woodside Site',
#        'desc': 'Community',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19331,
#        'text': 'Blackridge Civic Association',
#        'desc': 'Community Center',
#        'detail': '1200 Beulah Road, Pittsburgh PA, 15221',
#        'data': 'Community and Social Centers',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17803,
#        'text': 'Boone Alley Tot Lot',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19532,
#        'text': 'Braddock Avenue Express',
#        'desc': 'Convenience Store',
#        'detail': '1101 South Braddock Avenue, Pittsburgh PA, 15218',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17031,
#        'text': 'Braddock Carnegie Library',
#        'desc': None,
#        'detail': None,
#        'data': 'Libraries',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18591,
#        'text': 'Braddock Farms (Grow Pittsburgh)',
#        'desc': 'Farmers Market',
#        'detail': '600 Braddock Avenue, Braddock, PA 15104',
#        'data': 'Supermarkets and Convenience Stores',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19550,
#        'text': 'Braddock Hills Shopping Center',
#        'desc': None,
#        'detail': None,
#        'data': 'Job Centers / Retail',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17510,
#        'text': 'Bright Park',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17596,
#        'text': 'Brinton Avenue Playground',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17164,
#        'text': 'Bullock Pens Park',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17034,
#        'text': 'C C Mellor Library Forest Hills',
#        'desc': None,
#        'detail': None,
#        'data': 'Libraries',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17035,
#        'text': 'C C Mellor Memorial Library',
#        'desc': None,
#        'detail': None,
#        'data': 'Libraries',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17989,
#        'text': 'CCP Gil',
#        'desc': 'Primary Care',
#        'detail': '1000 Infinity Drive - First Floor, Monroeville, PA 15146',
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18239,
#        'text': 'CCP Monroeville',
#        'desc': 'Primary Care',
#        'detail': '2790 Mosside Boulevard - Suite 700, Monroeville, PA 15146',
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18345,
#        'text': 'CCP Monroeville Pediatric Assocs',
#        'desc': 'Primary Care',
#        'detail': '4075 Monroeville Blvd - Suite 125, Monroeville, PA 15146',
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19610,
#        'text': 'Caldwell Station',
#        'desc': 'FAMILY COMMUNITIES (Ages 18+ and Elderly 62+)',
#        'detail': 'Caldwell Ave, Wilmerding, PA  15235',
#        'data': 'Affordable Housing',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17710,
#        'text': 'Calhoun Field Community Park',
#        'desc': 'Municipal',
#        'detail': None,
#        'data': 'Parks',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19381,
#        'text': 'Calvary African Methodist Episcopal Church',
#        'desc': None,
#        'detail': None,
#        'data': 'Places of Worship',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 16465,
#        'text': 'Calvary Baptist Nursery & Kindergarten',
#        'desc': 'Nonpublic, Non-Licensed School',
#        'detail': '120 Anborn Dr, West Mifflin, PA 15122',
#        'data': 'Schools',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19382,
#        'text': 'Calvary United Church of Christ',
#        'desc': None,
#        'detail': None,
#        'data': 'Places of Worship',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17036,
#        'text': 'Carnegie Free Library of Swissvale',
#        'desc': None,
#        'detail': None,
#        'data': 'Libraries',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17038,
#        'text': 'Carnegie Library of Homestead',
#        'desc': None,
#        'detail': None,
#        'data': 'Libraries',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17039,
#        'text': 'Carnegie Library of McKeesport',
#        'desc': None,
#        'detail': None,
#        'data': 'Libraries',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 17040,
#        'text': 'Carnegie Library of McKeesport-Duquesne',
#        'desc': None,
#        'detail': None,
#        'data': 'Libraries',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 18364,
#        'text': 'Castiglione, Angelo MD',
#        'desc': 'Primary Care',
#        'detail': '4318 Northern Pike - Suite 200, Monroeville, PA 15146',
#        'data': 'Healthcare',
#        'formType': 'checkbox',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': 'ppt-concept-destinations',
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 19383,
#        'text': 'Center Avenue United Methodist Church',
#        'desc': None,
#        'detail': None,
# ...
#         {'value': 'Moon Township', 'label': 'Moon Township'},
#         {'value': 'Morningside (Pittsburgh)',
#          'label': 'Morningside (Pittsburgh)'},
#         {'value': 'Mount Lebanon', 'label': 'Mount Lebanon'},
#         {'value': 'Mount Oliver Borough', 'label': 'Mount Oliver Borough'},
#         {'value': 'Mount Washington (Pittsburgh)',
#          'label': 'Mount Washington (Pittsburgh)'},
#         {'value': 'Mt. Oliver (Pittsburgh)',
#          'label': 'Mt. Oliver (Pittsburgh)'},
#         {'value': 'Munhall Borough', 'label': 'Munhall Borough'},
#         {'value': 'Neville Township', 'label': 'Neville Township'},
#         {'value': 'New Homestead (Pittsburgh)',
#          'label': 'New Homestead (Pittsburgh)'},
#         {'value': 'North Braddock Borough', 'label': 'North Braddock Borough'},
#         {'value': 'North Fayette Township', 'label': 'North Fayette Township'},
#         {'value': 'North Oakland (Pittsburgh)',
#          'label': 'North Oakland (Pittsburgh)'},
#         {'value': 'North Shore (Pittsburgh)',
#          'label': 'North Shore (Pittsburgh)'},
#         {'value': 'North Versailles Township',
#          'label': 'North Versailles Township'},
#         {'value': 'Northview Heights (Pittsburgh)',
#          'label': 'Northview Heights (Pittsburgh)'},
#         {'value': 'O Hara Township', 'label': 'O Hara Township'},
#         {'value': 'Oakdale Borough', 'label': 'Oakdale Borough'},
#         {'value': 'Oakmont Borough', 'label': 'Oakmont Borough'},
#         {'value': 'Oakwood (Pittsburgh)', 'label': 'Oakwood (Pittsburgh)'},
#         {'value': 'Ohio Township', 'label': 'Ohio Township'},
#         {'value': 'Overbrook (Pittsburgh)', 'label': 'Overbrook (Pittsburgh)'},
#         {'value': 'Penn Hills Township', 'label': 'Penn Hills Township'},
#         {'value': 'Pennsbury Village Borough',
#          'label': 'Pennsbury Village Borough'},
#         {'value': 'Perry North (Pittsburgh)',
#          'label': 'Perry North (Pittsburgh)'},
#         {'value': 'Perry South (Pittsburgh)',
#          'label': 'Perry South (Pittsburgh)'},
#         {'value': 'Pine Township', 'label': 'Pine Township'},
#         {'value': 'Pitcairn Borough', 'label': 'Pitcairn Borough'},
#         {'value': 'Pleasant Hills Borough', 'label': 'Pleasant Hills Borough'},
#         {'value': 'Plum Borough', 'label': 'Plum Borough'},
#         {'value': 'Point Breeze (Pittsburgh)',
#          'label': 'Point Breeze (Pittsburgh)'},
#         {'value': 'Point Breeze North (Pittsburgh)',
#          'label': 'Point Breeze North (Pittsburgh)'},
#         {'value': 'Polish Hill (Pittsburgh)',
#          'label': 'Polish Hill (Pittsburgh)'},
#         {'value': 'Port Vue Borough', 'label': 'Port Vue Borough'},
#         {'value': 'Rankin Borough', 'label': 'Rankin Borough'},
#         {'value': 'Regent Square (Pittsburgh)',
#          'label': 'Regent Square (Pittsburgh)'},
#         {'value': 'Reserve Township', 'label': 'Reserve Township'},
#         {'value': 'Richland Township', 'label': 'Richland Township'},
#         {'value': 'Ridgemont (Pittsburgh)', 'label': 'Ridgemont (Pittsburgh)'},
#         {'value': 'Robinson Township', 'label': 'Robinson Township'},
#         {'value': 'Ross Township', 'label': 'Ross Township'},
#         {'value': 'Rosslyn Farms Borough', 'label': 'Rosslyn Farms Borough'},
#         {'value': 'Scott Township', 'label': 'Scott Township'},
#         {'value': 'Sewickley Borough', 'label': 'Sewickley Borough'},
#         {'value': 'Sewickley Heights Borough',
#          'label': 'Sewickley Heights Borough'},
#         {'value': 'Sewickley Hills Borough',
#          'label': 'Sewickley Hills Borough'},
#         {'value': 'Shadyside (Pittsburgh)', 'label': 'Shadyside (Pittsburgh)'},
#         {'value': 'Shaler Township', 'label': 'Shaler Township'},
#         {'value': 'Sharpsburg Borough', 'label': 'Sharpsburg Borough'},
#         {'value': 'Sheraden (Pittsburgh)', 'label': 'Sheraden (Pittsburgh)'},
#         {'value': 'South Fayette Township', 'label': 'South Fayette Township'},
#         {'value': 'South Oakland (Pittsburgh)',
#          'label': 'South Oakland (Pittsburgh)'},
#         {'value': 'South Park Township', 'label': 'South Park Township'},
#         {'value': 'South Shore (Pittsburgh)',
#          'label': 'South Shore (Pittsburgh)'},
#         {'value': 'South Side Flats (Pittsburgh)',
#          'label': 'South Side Flats (Pittsburgh)'},
#         {'value': 'South Side Slopes (Pittsburgh)',
#          'label': 'South Side Slopes (Pittsburgh)'},
#         {'value': 'South Versailles Township',
#          'label': 'South Versailles Township'},
#         {'value': 'Spring Garden (Pittsburgh)',
#          'label': 'Spring Garden (Pittsburgh)'},
#         {'value': 'Spring Hill-City View (Pittsburgh)',
#          'label': 'Spring Hill-City View (Pittsburgh)'},
#         {'value': 'Springdale Borough', 'label': 'Springdale Borough'},
#         {'value': 'Springdale Township', 'label': 'Springdale Township'},
#         {'value': 'Squirrel Hill North (Pittsburgh)',
#          'label': 'Squirrel Hill North (Pittsburgh)'},
#         {'value': 'Squirrel Hill South (Pittsburgh)',
#          'label': 'Squirrel Hill South (Pittsburgh)'},
#         {'value': 'St. Clair (Pittsburgh)', 'label': 'St. Clair (Pittsburgh)'},
#         {'value': 'Stanton Heights (Pittsburgh)',
#          'label': 'Stanton Heights (Pittsburgh)'},
#         {'value': 'Stowe Township', 'label': 'Stowe Township'},
#         {'value': 'Strip District (Pittsburgh)',
#          'label': 'Strip District (Pittsburgh)'},
#         {'value': 'Summer Hill (Pittsburgh)',
#          'label': 'Summer Hill (Pittsburgh)'},
#         {'value': 'Swisshelm Park (Pittsburgh)',
#          'label': 'Swisshelm Park (Pittsburgh)'},
#         {'value': 'Swissvale Borough', 'label': 'Swissvale Borough'},
#         {'value': 'Tarentum Borough', 'label': 'Tarentum Borough'},
#         {'value': 'Terrace Village (Pittsburgh)',
#          'label': 'Terrace Village (Pittsburgh)'},
#         {'value': 'Thornburg Borough', 'label': 'Thornburg Borough'},
#         {'value': 'Trafford Borough', 'label': 'Trafford Borough'},
#         {'value': 'Troy Hill (Pittsburgh)', 'label': 'Troy Hill (Pittsburgh)'},
#         {'value': 'Turtle Creek Borough', 'label': 'Turtle Creek Borough'},
#         {'value': 'Upper Hill (Pittsburgh)',
#          'label': 'Upper Hill (Pittsburgh)'},
#         {'value': 'Upper Lawrenceville (Pittsburgh)',
#          'label': 'Upper Lawrenceville (Pittsburgh)'},
#         {'value': 'Upper St. Clair Township',
#          'label': 'Upper St. Clair Township'},
#         {'value': 'Verona Borough', 'label': 'Verona Borough'},
#         {'value': 'Versailles Borough', 'label': 'Versailles Borough'},
#         {'value': 'Wall Borough', 'label': 'Wall Borough'},
#         {'value': 'West Deer Township', 'label': 'West Deer Township'},
#         {'value': 'West Elizabeth Borough', 'label': 'West Elizabeth Borough'},
#         {'value': 'West End (Pittsburgh)', 'label': 'West End (Pittsburgh)'},
#         {'value': 'West Homestead Borough', 'label': 'West Homestead Borough'},
#         {'value': 'West Mifflin Borough', 'label': 'West Mifflin Borough'},
#         {'value': 'West Oakland (Pittsburgh)',
#          'label': 'West Oakland (Pittsburgh)'},
#         {'value': 'West View Borough', 'label': 'West View Borough'},
#         {'value': 'Westwood (Pittsburgh)', 'label': 'Westwood (Pittsburgh)'},
#         {'value': 'Whitaker Borough', 'label': 'Whitaker Borough'},
#         {'value': 'White Oak Borough', 'label': 'White Oak Borough'},
#         {'value': 'Whitehall Borough', 'label': 'Whitehall Borough'},
#         {'value': 'Wilkins Township', 'label': 'Wilkins Township'},
#         {'value': 'Wilkinsburg Borough', 'label': 'Wilkinsburg Borough'},
#         {'value': 'Wilmerding Borough', 'label': 'Wilmerding Borough'},
#         {'value': 'Windgap (Pittsburgh)', 'label': 'Windgap (Pittsburgh)'}],
#        'desc': 'Where are you from?',
#        'formType': 'react-select-text',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': None,
#        'skipFilter': None,
#        'fgidx': 0}],
#      'layerSource': False,
#      'desc': False,
#      'type': 'text-group',
#      'optional': False,
#      'answered': False,
#      'fgidx': 0},
#     {'id': 2,
#      'forms': [{'id': 820,
#        'text': [{'value': 'Under 12 years old', 'label': 'Under 12 years old'},
#         {'value': '12-17 years old', 'label': '12-17 years old'},
#         {'value': '18-24 years old', 'label': '18-24 years old'},
#         {'value': '25-34 years old', 'label': '25-34 years old'},
#         {'value': '35-44 years old', 'label': '35-44 years old'},
#         {'value': '45-54 years old', 'label': '45-54 years old'},
#         {'value': '55-64 years old', 'label': '55-64 years old'},
#         {'value': '65-74 years old', 'label': '65-74 years old'},
#         {'value': '75 years or older', 'label': '75 years or older'}],
#        'desc': 'How old are you?',
#        'formType': 'react-select',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': None,
#        'skipFilter': None,
#        'fgidx': 1}],
#      'layerSource': False,
#      'desc': False,
#      'type': 'text-group',
#      'optional': False,
#      'answered': False,
#      'fgidx': 1},
#     {'id': 3,
#      'forms': [{'id': 830,
#        'text': [{'value': 'Full-time employment',
#          'label': 'Full-time employment'},
#         {'value': 'Part-time employment', 'label': 'Part-time employment'},
#         {'value': 'Part-time employment (more than one employer)',
#          'label': 'Part-time employment (more than one employer)'},
#         {'value': 'Unemployed', 'label': 'Unemployed'},
#         {'value': 'Retired', 'label': 'Retired'},
#         {'value': 'Self-Employed', 'label': 'Self-Employed'},
#         {'value': 'Student', 'label': 'Student'},
#         {'value': 'Prefer Not to Answer', 'label': 'Prefer Not to Answer'}],
#        'desc': 'Employment status?',
#        'formType': 'react-select',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': None,
#        'skipFilter': None,
#        'fgidx': 2}],
#      'layerSource': False,
#      'desc': False,
#      'type': 'text-group',
#      'optional': False,
#      'answered': False,
#      'fgidx': 2}],
#    'mapView': False,
#    'optional': False,
#    'answered': False,
#    'answerCountLimit': False,
#    'categoryFilter': False,
#    'highlightOnSelect': True},
#   {'id': 12,
#    'title': 'Tell us just a little about you.',
#    'content': '',
#    'desc': "Help us understand who we're advocating with! We also want to make sure that folks from all walks of life are part of this rider-led planning process. *This information will remain anonymous.*",
#    'formGroups': [{'id': 5,
#      'forms': [{'id': 840,
#        'text': [{'value': 'Man', 'label': 'Man'},
#         {'value': 'Woman', 'label': 'Woman'},
#         {'value': 'Gender Non-Conforming', 'label': 'Gender Non-Conforming'},
#         {'value': 'Prefer not to say', 'label': 'Prefer not to say'}],
#        'desc': 'Gender',
#        'detail': 'Select gender from the list, or type to write-in your own answer',
#        'formType': 'react-select-text',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': None,
#        'skipFilter': None,
#        'fgidx': 0}],
#      'layerSource': False,
#      'desc': False,
#      'type': 'text-group',
#      'optional': False,
#      'answered': False,
#      'fgidx': 0},
#     {'id': 6,
#      'forms': [{'id': 850,
#        'text': [{'value': 'White', 'label': 'White'},
#         {'value': 'Hispanic, Latino, or Spanish',
#          'label': 'Hispanic, Latino, or Spanish'},
#         {'value': 'Black or African American',
#          'label': 'Black or African American'},
#         {'value': 'Asian', 'label': 'Asian'},
#         {'value': 'American Indian or Alaskan Native',
#          'label': 'American Indian or Alaskan Native'},
#         {'value': 'Middle Eastern or North African',
#          'label': 'Middle Eastern or North African'},
#         {'value': 'Native Hawaiian or other Pacific Islander',
#          'label': 'Native Hawaiian or other Pacific Islander'},
#         {'value': 'Other', 'label': 'Other'}],
#        'desc': 'Race',
#        'detail': 'Select as many as you need to from the list, or type to write-in your own answer',
#        'formType': 'react-select-text-create',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': None,
#        'skipFilter': None,
#        'fgidx': 1}],
#      'layerSource': False,
#      'desc': False,
#      'type': 'text-group',
#      'optional': False,
#      'answered': False,
#      'fgidx': 1}],
#    'mapView': False,
#    'optional': False,
#    'answered': False,
#    'answerCountLimit': False,
#    'categoryFilter': False,
#    'highlightOnSelect': True},
#   {'id': 15,
#    'title': 'Questions? Comments?',
#    'content': '',
#    'desc': 'Anything else you want to add about transit in the region?',
#    'formGroups': [{'id': 1,
#      'forms': [{'id': 1000,
#        'text': None,
#        'formType': 'textarea',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': None,
#        'skipFilter': None,
#        'fgidx': 0}],
#      'layerSource': False,
#      'desc': False,
#      'type': 'text-group',
#      'optional': True,
#      'answered': False,
#      'fgidx': 0}],
#    'mapView': False,
#    'optional': True,
#    'answered': False,
#    'answerCountLimit': False,
#    'categoryFilter': False,
#    'highlightOnSelect': True},
#   {'id': 14,
#    'title': 'Thank you!',
#    'content': '',
#    'desc': "Thanks for taking this step in building a Riders' Vision for better transit beyond the East Busway!\n\n**If we're going to make this a happen, we need you.**\n\nLeave your contact information to get involved in the campaign, and we'll reach out to you about next steps.\n\n> *Note that by providing this information you agree that is is OK to be contacted by Pittsburghers for Public Transit. This contact information will not be given or sold to any third party.*",
#    'formGroups': [{'id': 1,
#      'forms': [{'id': 870,
#        'text': None,
#        'desc': 'Your name:',
#        'formType': 'text',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': None,
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 880,
#        'text': None,
#        'desc': 'You e-mail address:',
#        'formType': 'email',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': None,
#        'skipFilter': None,
#        'fgidx': 0},
#       {'id': 890,
#        'text': None,
#        'desc': 'You phone:',
#        'formType': 'tel',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': None,
#        'skipFilter': None,
#        'fgidx': 0}],
#      'layerSource': False,
#      'desc': False,
#      'type': 'text-group',
#      'optional': True,
#      'answered': False,
#      'fgidx': 0}],
#    'mapView': False,
#    'optional': True,
#    'answered': False,
#    'answerCountLimit': False,
#    'categoryFilter': False,
#    'highlightOnSelect': True},
#   {'id': 16,
#    'title': 'Send it!',
#    'content': '',
#    'desc': 'Press **Submit** below to send this info along. If you want to make any changes, you can hit **Back** button below and modify your answers.',
#    'formGroups': [{'id': 1,
#      'forms': [{'id': 99999,
#        'text': 'Submit',
#        'formType': 'submit',
#        'checked': False,
#        'disabled': False,
#        'visible': False,
#        'answer': None,
#        'layerId': None,
#        'skipFilter': None,
#        'fgidx': 0}],
#      'layerSource': False,
#      'desc': False,
#      'type': 'text-group',
#      'optional': False,
#      'answered': False,
#      'fgidx': 0}],
#    'mapView': False,
#    'optional': False,
#    'answered': False,
#    'answerCountLimit': False,
#    'categoryFilter': False,
#    'highlightOnSelect': True}]}

# %%
data = pd.read_csv("../Data/civic_survey.csv", encoding = "ISO-8859-1")
[x for x in enumerate(data.columns)]
# Out:
# [(0, 'id'),
#  (1, 'timestamp'),
#  (2, '3 - Area of interest'),
#  (3, '4 - Communities of interest'),
#  (4, '5 - Destinations'),
#  (5, '6 - Corridor preference'),
#  (6, '7 - Pittsburgh areas'),
#  (7, '8 - Allegheny County areas'),
#  (8, '9 - PAAC Routes Used'),
#  (9, '10 - Routing Type Preference'),
#  (10, '11 - Current Transit Frequency'),
#  (11, '11 - Current Transit Usage'),
#  (12, '12 - Other Transport Used'),
#  (13, '12 - Why Other Transport Used'),
#  (14, '13 - Age'),
#  (15, '13 - Employment status'),
#  (16, '13 - Where From'),
#  (17, '14 - Gender'),
#  (18, '14 - Race'),
#  (19, '15 - Comments')]

# %%
dFrame = hp.firstNormal(data, col_indeces=[4, 13])
dFrame.head()
# Out:
#                                         Destinations  \
# 0                                     Aldi Store #97
# 1  Centers for Rehab Services Forest Hills, 2020 ...
# 2  Shop \n Save, 3335 William Penn Hwy, Pittsburg...
# 3                                     Barrett El Sch
# 4                                     Barrett El Sch
#
#                             Why_Other_Transport_Used
# 0  Transit isnt reliable to get me where Im going...
# 1  Transit isnt reliable to get me where Im going...
# 2  Transit isnt reliable to get me where Im going...
# 3                   Transit doesnt come often enough
# 4                                           Too slow

# %% [markdown]
# ## Filtering for Monroeville Mall

# %%
mon_mall = dFrame[[bool(re.match(pattern = "monroeville mall", string = x.lower())) for x in dFrame.Destinations]]

# %%
mon_mall.groupby("Why_Other_Transport_Used").count().reset_index().sort_values("Destinations", ascending=False)
# Out:
#                             Why_Other_Transport_Used  Destinations
# 4  Public transit is not available where I am tra...            45
# 8                   Transit doesnt come often enough            45
# 7                                           Too slow            40
# 2          No transit service at the times I need it            36
# 9  Transit isnt reliable to get me where Im going...            29
# 1            I usually need to carry too many things            21
# 5  The stops/stations are hard to get to because ...            20
# 3                                              Other            17
# 6                                      Too expensive            11
# 0                          I only use public transit             3
